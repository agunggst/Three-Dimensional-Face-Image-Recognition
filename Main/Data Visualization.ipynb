# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rd
import statistics

# %%
#index [0] = 3070 Col, [1] = 3070 Row, [2] = 5050 Col, [3] = 5050 Row
sixlayers_max = [[96.933, 88.213, 46.053, 89.867, 96.827], 
                 [89.081, 80.59, 43.676, 82.243, 88.892], 
                 [99.519, 92.481, 46.259, 93.444, 99.556], 
                 [97.336, 88.88, 47.104, 89.151, 97.413]]
sixlayers_avg = [[96.613, 87.28, 45.493, 88.24, 96.667], 
                 [88.568, 80.135, 44.622, 80.784, 88.541], 
                 [99.259, 91.148, 45.037, 92.963, 99.222], 
                 [97.375, 86.409, 47.683, 88.185, 97.336]]

# %%
reg = np.arange(5)
noise = 'None', 'Gauss .01', 'Gauss .05', 'S&P', 'Speckle'

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg-0.125, sixlayers_max[0], width = 0.25, color = '#ff8566', label = 'Max')
plt.bar(reg+0.125, sixlayers_avg[0], width = 0.25, color = '#8080ff',label = 'Avg')
plt.xticks(reg, noise)
plt.ylabel("Validation Acc (%)")
plt.title('Enam Layer MaxPool vs AvgPool\nDataset 3070C', fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg-0.125, sixlayers_max[1], width = 0.25, color = '#ff8566', label = 'Max')
plt.plot(reg,[k,k,k,k,k], color = '#ff8566', linestyle='--')
plt.bar(reg+0.125, sixlayers_avg[1], width = 0.25, color = '#8080ff',label = 'Avg')
plt.plot(reg,[s,s,s,s,s], color = '#000000', linestyle='-.')
plt.xticks(reg, noise)
plt.ylabel("Validation Acc (%)")
plt.title('Enam Layer MaxPool vs AvgPool\nDataset 3070R', fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg-0.125, sixlayers_max[2], width = 0.25, color = '#ff8566', label = 'Max')
plt.bar(reg+0.125, sixlayers_avg[2], width = 0.25, color = '#8080ff',label = 'Avg')
plt.xticks(reg, noise)
plt.ylabel("Validation Acc (%)")
plt.title('Enam Layer MaxPool vs AvgPool\nDataset 5050C', fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg-0.125, sixlayers_max[3], width = 0.25, color = '#ff8566', label = 'Max')
plt.bar(reg+0.125, sixlayers_avg[3], width = 0.25, color = '#8080ff',label = 'Avg')
plt.xticks(reg, noise)
plt.ylabel("Validation Acc (%)")
plt.title('Enam Layer MaxPool vs AvgPool\nDataset 5050R', fontsize=12)
plt.legend()
plt.show()

# %%
statistics.mean(sixlayers_avg[0])
# Out:
# 82.8586

# %%
s=statistics.mean(sixlayers_max[1])

# %%
s=statistics.mean(sixlayers_avg[2])
# Out:
# 85.5258

# %%
statistics.mean(sixlayers_avg[3])
# Out:
# 83.3976

# %% [markdown]
# # Membadingkan Keempat Dataset

# %% [markdown]
# Aristektur 6 layer MaxPool:

# %%
sixN = [96.933, 89.081, 99.519, 97.336]
sixG1 = [88.213, 80.59, 92.481, 88.88]
sixG5 = [46.053, 43.676, 46.259, 47.104]
sixSP = [89.867, 82.243, 93.444, 89.151]
sixS = [96.827, 88.892, 99.556, 97.413]
sixlayers_max = [[96.933, 88.213, 46.053, 89.867, 96.827], 
                 [89.081, 80.59, 43.676, 82.243, 88.892], 
                 [99.519, 92.481, 46.259, 93.444, 99.556], 
                 [97.336, 88.88, 47.104, 89.151, 97.413]]
Rata2 = [statistics.mean(sixlayers_max[0]), 
         statistics.mean(sixlayers_max[1]), 
         statistics.mean(sixlayers_max[2]), 
         statistics.mean(sixlayers_max[3])]

# %%
reg = np.arange(4)
ticks = 'Kolom_3070 Baris_3070 Kolom_5050 Baris_5050'.split()

# %%
plt.figure(figsize = (8, 5))
plt.bar(reg-0.3, sixN, width = 0.15, color = '#00001a', label = 'Normal')
plt.bar(reg-0.15, sixG1, width = 0.15, color = '#000080', label = 'Gaussian .01')
plt.bar(reg+0.0, sixG5, width = 0.15, color = '#0000e6', label = 'Gaussian .05')
plt.bar(reg+0.15, sixSP, width = 0.15, color = '#4d4dff',label = 'Salt & Pepper')
plt.bar(reg+0.3, sixS, width = 0.15, color = '#8080ff', label = 'Speckle')
plt.plot(reg, Rata2, color = '#ffff00', label = 'Rata-Rata')
plt.scatter(reg, Rata2, color = '#0000ff')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Grafik Perbandingan Keempat Dataset\nPada Struktur CNN 6 Layer MaxPool', fontsize=14)
plt.legend(loc = (1.02,0.7))
plt.show()

# %% [markdown]
# Aristektur 7 layer MaxPool:

# %%
sevenN = [97.467, 88.811, 99.667, 97.375]
sevenG1 = [87.76, 80.297, 91.778, 86.409]
sevenG5 = [42.853, 42.378, 42.778, 43.398]
sevenSP = [87.787, 79.838, 90.63, 86.332]
sevenS = [97.44, 88.703, 99.704, 97.49]
sevenlayers_max = [[97.467, 87.76, 42.853, 87.787, 97.44], 
                 [88.811, 80.297, 42.378, 79.838, 88.703], 
                 [99.667, 91.778, 42.778, 90.63, 99.704], 
                 [97.375, 86.409, 43.398, 86.332, 97.49]]
Rata2 = [statistics.mean(sevenlayers_max[0]), 
         statistics.mean(sevenlayers_max[1]), 
         statistics.mean(sevenlayers_max[2]), 
         statistics.mean(sevenlayers_max[3])]

# %%
reg = np.arange(4)
ticks = 'Kolom_3070 Baris_3070 Kolom_5050 Baris_5050'.split()

# %%
plt.figure(figsize = (8, 5))
plt.bar(reg-0.3, sevenN, width = 0.15, color = '#00001a', label = 'Normal')
plt.bar(reg-0.15, sevenG1, width = 0.15, color = '#000080', label = 'Gaussian .01')
plt.bar(reg+0.0, sevenG5, width = 0.15, color = '#0000e6', label = 'Gaussian .05')
plt.bar(reg+0.15, sevenSP, width = 0.15, color = '#4d4dff',label = 'Salt & Pepper')
plt.bar(reg+0.3, sevenS, width = 0.15, color = '#8080ff', label = 'Speckle')
plt.plot(reg, Rata2, color = '#ffff00', label = 'Rata-Rata')
plt.scatter(reg, Rata2, color = '#0000ff')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Grafik Perbandingan Keempat Dataset\nPada Struktur CNN 7 Layer MaxPool', fontsize=14)
plt.legend(loc = (1.02,0.7))
plt.show()

# %% [markdown]
# Arsitektur 8 Layer MaxPool:

# %%
eightN = [96, 85.027, 99.556, 95.058]
eightG1 = [83.973, 74.568, 86.556, 83.282]
eightG5 = [36.933, 35.243, 36.148, 38.378]
eightSP = [85.787, 68.784, 89.037, 88.031]
eightS = [96.027, 84.703, 99.519, 95.058]
eightlayers_max = [[96, 83.973, 36.933, 85.787, 96.027], 
                 [85.027, 74.568, 35.243, 68.784, 84.703], 
                 [99.556, 86.556, 36.148, 89.037, 99.519], 
                 [95.058, 83.282, 38.378, 88.031, 95.058]]
Rata2 = [statistics.mean(eightlayers_max[0]), 
         statistics.mean(eightlayers_max[1]), 
         statistics.mean(eightlayers_max[2]), 
         statistics.mean(eightlayers_max[3])]

# %%
reg = np.arange(4)
ticks = 'Kolom_3070 Baris_3070 Kolom_5050 Baris_5050'.split()

# %%
plt.figure(figsize = (8, 5))
plt.bar(reg-0.3, eightN, width = 0.15, color = '#00001a', label = 'Normal')
plt.bar(reg-0.15, eightG1, width = 0.15, color = '#000080', label = 'Gaussian .01')
plt.bar(reg+0.0, eightG5, width = 0.15, color = '#0000e6', label = 'Gaussian .05')
plt.bar(reg+0.15, eightSP, width = 0.15, color = '#4d4dff',label = 'Salt & Pepper')
plt.bar(reg+0.3, eightS, width = 0.15, color = '#8080ff', label = 'Speckle')
plt.plot(reg, Rata2, color = '#ffff00', label = 'Rata-Rata')
plt.scatter(reg, Rata2, color = '#0000ff')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Grafik Perbandingan Keempat Dataset\nPada Struktur CNN 8 Layer MaxPool', fontsize=14)
plt.legend(loc = (1.02,0.7))
plt.show()

# %% [markdown]
# Arsitektur 9 Layer MaxPool:

# %%
nineN = [96.507, 85.459, 99.741, 94.093]
nineG1 = [86.32, 77.649, 90.667, 77.49]
nineG5 = [44.853, 40.297, 45.667, 31.583]
nineSP = [91.173, 76.757, 94.296, 74.479]
nineS = [96.267, 85.595, 99.667, 94.093]
ninelayers_max = [[96.507, 86.32, 44.853, 91.173, 96.267], 
                 [85.459, 77.649, 40.297, 76.757, 85.595], 
                 [99.741, 90.667, 45.667, 94.296, 99.667], 
                 [94.093, 77.49, 31.583, 74.479, 94.093]]
Rata2 = [statistics.mean(ninelayers_max[0]), 
         statistics.mean(ninelayers_max[1]), 
         statistics.mean(ninelayers_max[2]), 
         statistics.mean(ninelayers_max[3])]

# %%
reg = np.arange(4)
ticks = 'Kolom_3070 Baris_3070 Kolom_5050 Baris_5050'.split()

# %%
plt.figure(figsize = (8, 5))
plt.bar(reg-0.3, nineN, width = 0.15, color = '#00001a', label = 'Normal')
plt.bar(reg-0.15, nineG1, width = 0.15, color = '#000080', label = 'Gaussian .01')
plt.bar(reg+0.0, nineG5, width = 0.15, color = '#0000e6', label = 'Gaussian .05')
plt.bar(reg+0.15, nineSP, width = 0.15, color = '#4d4dff',label = 'Salt & Pepper')
plt.bar(reg+0.3, nineS, width = 0.15, color = '#8080ff', label = 'Speckle')
plt.plot(reg, Rata2, color = '#ffff00', label = 'Rata-Rata')
plt.scatter(reg, Rata2, color = '#0000ff')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Grafik Perbandingan Keempat Dataset\nPada Struktur CNN 9 Layer MaxPool', fontsize=14)
plt.legend(loc = (1.02,0.7))
plt.show()

# %% [markdown]
# Berdasarkan keempat grafik diatas dari keseluruhan struktur yang digunakan untuk melakukan pelatihan, dapat diambil kesimpulan bahwa dataset Pelatihan secara Yaw/kolom dengan pengambilan selang-seling (±50% Train) adalah dataset terbaik.

# %% [markdown]
# Sebagai tandingan, coba kita lihat hasil dataset Pelatihan secara Yaw dengan pengambilan data train selang 2 kali (±30 Train) dengan mempertimbangkan waktu komputasi dan validation acc.

# %% [markdown]
# # Membandingkan keempat struktur CNN 6,7,8,9 layer

# %%
#[0] = 6, [1] = 7, [2] = 7, [3] = 9
Normal = [99.519, 99.667,99.556, 99.741]

Gauss_1 = [92.481, 91.778, 86.556, 90.667,]

Gauss_5 = [46.259, 42.778, 36.148, 45.667]

SP = [93.444, 90.63, 89.037, 94.296]

Speckle = [99.556, 99.704, 99.519, 99.667]

# %%
reg = np.arange(4)
ticks = '6Layer 7Layer 8Layer 9Layer'.split()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg, Normal, width = 0.25, color = '#ff8566', label = 'Max')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Perbadingan Keempat Struktur CNN', fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg, Gauss_1, width = 0.25, color = '#ff8566', label = 'Max')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Perbadingan Keempat Struktur CNN\nDengan Gaussian Noise var=0.01', fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg, Gauss_5, width = 0.25, color = '#ff8566', label = 'Max')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Perbadingan Keempat Struktur CNN\nDengan Gaussian Noise var=0.05', fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg, SP, width = 0.25, color = '#ff8566', label = 'Max')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Perbadingan Keempat Struktur CNN\nDengan Salt and Pepper Noise', fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg, Speckle, width = 0.25, color = '#ff8566', label = 'Max')
plt.xticks(reg, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Perbadingan Keempat Struktur CNN\nDengan Speckle Noise', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Kesimpulan: terbagus 6 layer

# %% [markdown]
# waktu pelatihan juga yang paling singkat

# %% [markdown]
# # Analisa MaxPool vs AvgPool

# %%
#index [0] = 3070 Col, [1] = 3070 Row, [2] = 5050 Col, [3] = 5050 Row
sixlayers_max = [[96.933, 88.213, 46.053, 89.867, 96.827], 
                 [89.081, 80.59, 43.676, 82.243, 88.892], 
                 [99.519, 92.481, 46.259, 93.444, 99.556], 
                 [97.336, 88.88, 47.104, 89.151, 97.413]]
sixlayers_avg = [[96.613, 87.28, 45.493, 88.24, 96.667], 
                 [88.568, 80.135, 44.622, 80.784, 88.541], 
                 [99.259, 91.148, 45.037, 92.963, 99.222], 
                 [97.375, 86.409, 47.683, 88.185, 97.336]]

# %%
reg = np.arange(5)
noise = 'None', 'Gauss .01', 'Gauss .05', 'S&P', 'Speckle'

# %%
plt.figure(figsize = (10, 6))
plt.bar(reg-0.125, sixlayers_max[2], width = 0.25, color = '#ff8566', label = 'Max')
plt.bar(reg+0.125, sixlayers_avg[2], width = 0.25, color = '#8080ff',label = 'Avg')
plt.xticks(reg, noise)
plt.ylabel("Validation Acc (%)")
plt.title('Enam Layer MaxPool vs AvgPool\nDataset Yaw ±50% Pelatihan', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Winner: MaxPool

# %%
import matplotlib.pyplot as plt
import numpy as np

# create 1000 equally spaced points between -10 and 10
x = ["29970\n(7layer)", "31920\n(6layer)", "40800\n(9layer)", "43750\n(8layer)"]

# calculate the y value for each element of the x vector
y = [81.45, 82.68, 79.13, 77.88]

plt.plot(x, y)
plt.title('Grafik Pengaruh BPNN Neuron Input \nTerhadap Akurasi Rata-Rata', fontsize=14)
plt.xlabel('BPNN neuron input')
plt.ylabel("Akurasi rata-rata (%)")
# Out:
# Text(0, 0.5, 'Akurasi rata-rata (%)')

# %%
x = np.arange(4)
y = [82.68, 81.45, 77.88, 79.13]
y2 = [31920, 29970, 43750, 40800]
ticks = '3Layer 4Layer 5Layer 6Layer'.split()
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Struktur Ekstraksi Fitur CNN')
ax1.set_ylabel("Akurasi rata-rata (%)", color=color)
ax1.bar(x, y, width = 0.25, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Neuron Input Klasifikasi', color=color)  # we already handled the x-label with ax1
ax2.bar(x+0.25, y2, width = 0.25, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.xticks(x, ticks)
plt.title('Grafik Pengaruh BPNN Neuron Input \nTerhadap Akurasi Rata-Rata CNN 2 Hidden Layer', fontsize=14)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
x = np.arange(4)
y = [77.81, 75.7, 74.38, 74.5]
y2 = [31920, 29970, 43750, 40800]
ticks = '3Layer 4Layer 5Layer 6Layer'.split()
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Struktur Ekstraksi Fitur CNN')
ax1.set_ylabel("Akurasi rata-rata (%)", color=color)
ax1.bar(x, y, width =0.25, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Neuron Input Klasifikasi', color=color)  # we already handled the x-label with ax1
ax2.bar(x+0.25, y2, width=0.25, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.xticks(x, ticks)
plt.title('Grafik Pengaruh BPNN Neuron Input \nTerhadap Akurasi Rata-Rata CNN 1 Hidden Layer', fontsize=14)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
Normal = [61.89, 61.24, 64.04, 61.7]
Gauss1 = [52.72, 52.2, 53.44, 53.67]
Gauss5 = [38.24, 36.6, 37.33, 37.37]
sandp = [54.13, 52.24, 52.24, 54.15]
speckle = [61.87, 60.84, 64, 61.58]
BPNN1H = [[61.89, 61.24, 64.04, 61.7],
         [52.72, 52.2, 53.44, 53.67],
         [38.24, 36.6, 37.33, 37.37],
         [54.13, 52.24, 52.24, 54.15],
         [61.87, 60.84, 64, 61.58]]
x = [1,2,3,4]
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, Normal, width = 0.25, color = '#200377', label = 'Normal')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Validasi Keempat Dataset\nDengan kondisi Normal', fontsize=12)
plt.show()

# %%
x = [1,2,3,4]
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, Gauss1, width = 0.25, color = '#770303', label = 'Normal')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Validasi Keempat Dataset\nDengan Derau Gauss var=0.01', fontsize=12)
plt.show()

# %%
x = [1,2,3,4]
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, Gauss5, width = 0.25, color = '#d10202', label = 'Normal')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Validasi Keempat Dataset\nDengan Derau Gauss var=0.05', fontsize=12)
plt.show()

# %%
x = [1,2,3,4]
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, sandp, width = 0.25, color = '#474047', label = 'Normal')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Validasi Keempat Dataset\nDengan Derau Salt&Pepper', fontsize=12)
plt.show()

# %%
x = [1,2,3,4]
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, speckle, width = 0.25, color = '#197702', label = 'Normal')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Validasi Keempat Dataset\nDengan Derau Speckle', fontsize=12)
plt.show()

# %%
BPNN1H = [[61.89, 61.24, 64.04, 61.7],
         [52.72, 52.2, 53.44, 53.67],
         [38.24, 36.6, 37.33, 37.37],
         [54.13, 52.24, 52.24, 54.15],
         [61.87, 60.84, 64, 61.58]]
BPNN2H = [[91.89, 84.78, 97.33, 93.475],
          [82.13, 75.08, 88.48, 81.4],
          [49.15, 45.27, 53.2, 50.7],
          [80.53, 73.84, 87.67, 80.58],
          [91.71, 84.46, 97.074, 93.28]]

# %%
x = np.arange(4)
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[0], width = 0.25, color = '#1a0168', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[0], width = 0.25, color = '#3b00ef', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Kondisi Normal', fontsize=12)
plt.legend(loc = (1.02,0.7))
plt.show()

# %%
x = np.arange(4)
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[1], width = 0.25, color = '#840101', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[1], width = 0.25, color = '#fc0505', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Derau Gauss Var=0.01', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()

# %%
x = np.arange(4)
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[2], width = 0.25, color = '#823535', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[2], width = 0.25, color = '#f26060', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Derau Gauss Var=0.05', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()

# %%
x = np.arange(4)
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[3], width = 0.25, color = '#565050', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[3], width = 0.25, color = '#ad9f9f', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Derau Salt&Pepper', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()

# %%
x = np.arange(4)
ticks = 'Yaw±30% Pitch±30% Yaw±50% Pitch±50%'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[4], width = 0.25, color = '#024c07', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[4], width = 0.25, color = '#06a010', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Derau Speckle', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()

# %%
BPNN1H = [77.81, 75.7, 74.38, 74.5]
BPNN2H = [82.68, 81.45, 77.88, 79.13]

x = np.arange(4)
ticks = '3Layer 4Layer 5Layer 6Layer'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H, width = 0.25, color = '#024c07', label = 'CNN 2 Hidden Layer')
plt.bar(x+0.25, BPNN1H, width = 0.25, color = '#06a010', label = 'CNN 1 Hidden Layer')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Akurasi rata-rata CNN 1 H vs CNN 2 H', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()

# %%
BPNN = [53.63, 79.1]
#BPNN2H = [82.68, 81.45, 77.88, 79.13]

x = np.arange(2)
ticks = '1Hidden 2Hidden'.split()

plt.figure(figsize = (4, 3))
plt.bar(x, BPNN, width = 0.25, color = '#024c07')
#plt.bar(x+0.25, BPNN1H, width = 0.25, color = '#06a010', label = 'CNN 1 Hidden Layer')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('Akurasi rata-rata BPNN', fontsize=12)
#plt.legend(loc = (1.07,0.7))
plt.show()

# %%
x = [1,2,3,4]
y = [82.68, 81.45, 77.88, 79.13]
y2 = [31920, 29970, 43750, 40800]

ticks = '3Layer 4Layer 5Layer 6Layer'.split()
plt.figure(figsize = (4, 3))
plt.bar(x, BPNN2H[2], width = 0.25, color = '#823535', label = 'BPNN 2H')
plt.bar(x+0.25, BPNN1H[2], width = 0.25, color = '#f26060', label = 'BPNN 1H')
plt.xticks(x, ticks)
plt.ylabel("Validation Acc (%)")
plt.title('BPNN 1 H vs BPNN 2 H\nDengan Derau Gauss Var=0.05', fontsize=12)
plt.legend(loc = (0.3,-0.35))
plt.show()
